# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pymongo import MongoClient
import os

# %%
#client = MongoClient('mongodb://localhost:27017/')
client = MongoClient('mongodb+srv://almasfathima4:FcdtbJe82S8LL9Tu@cluster0.ibydlud.mongodb.net/')
db = client['StockMarketDatabase']
collection = db['StockMarketCollection']

# %% [markdown]
# Loading stocks data into collection

# %%
folder_path = 'C:/Users/almas/Downloads/archive17/Data/Stocks'

# %%
# Iterate through files in the folderFcdtbJe82S8LL9Tu
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)

        # Read CSV file into pandas DataFrame
        df = pd.read_csv(file_path)
        

        # Check if the DataFrame is empty
        if df.empty:
            print(f"Skipping empty file: {filename}")
            continue

        # Extract the ticker symbol from the filename
        ticker_symbol = filename.split('.')[0]

        # Add the 'Ticker' column to the DataFrame
        df['Ticker'] = ticker_symbol
        df['Date'] = pd.to_datetime(df['Date'])

        # Convert pandas DataFrame to list of dictionaries
        data = df.to_dict('records')

        # Insert data into MongoDB collection
        collection.insert_many(data)
# Out:
# Skipping empty file: AINC.csv
# Skipping empty file: AIV.csv
# Skipping empty file: AKO.csv
# Skipping empty file: ATCO.csv
# Skipping empty file: ATH.csv
# Skipping empty file: BF.csv
# Skipping empty file: CDR.csv
# Skipping empty file: GLOG.csv
# Skipping empty file: GLOP.csv
# Skipping empty file: I.csv
# Skipping empty file: ICR.csv
# Skipping empty file: LLAP.csv
# Skipping empty file: N.csv
# Skipping empty file: OAK.csv
# Skipping empty file: Q.csv
# Skipping empty file: RMPL.csv
# Skipping empty file: SEAL.csv
# Skipping empty file: Y.csv

# %%
df.head()

# %%
import os
total_files = len(os.listdir(folder_path))
loaded_documents = collection.count_documents({})

if loaded_documents == total_files:
    print("All CSV files successfully loaded into MongoDB.")
else:
    print(f"Only {loaded_documents} documents loaded out of {total_files} files.")

# %% [markdown]
# Loading stocksHistory data into collection2

# %%
collection2 = db['StockMarketHistoryCollection']

# %%
folder_path = 'C:/Users/almas/Downloads/archive17/Data/StockHistory'

# %%
# Iterate through files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)

        # Read CSV file into pandas DataFrame
        df2 = pd.read_csv(file_path)

        # Check if the DataFrame is empty
        if df2.empty:
            print(f"Skipping empty file: {filename}")
            continue

        # Extract the ticker symbol from the filename
        ticker_symbol = filename.split('.')[0]

        # Add the 'Ticker' column to the DataFrame
        df2['Ticker'] = ticker_symbol
        df['Date'] = pd.to_datetime(df['Date'])

 # Filter data based on Date condition (after Jan 1st, 2005)
        df2_filtered = df2[df2['Date'] > datetime(2005, 1, 1)]

        # Convert filtered pandas DataFrame to list of dictionaries
        data2 = df2_filtered.to_dict('records')

        # Insert filtered data into MongoDB collection
        if data2:
            collection2.insert_many(data2)
            print(f"Inserted data for {ticker_symbol} after Jan 1st, 2005 into collection2.")
        else:
            print(f"No data after Jan 1st, 2005 for {ticker_symbol}.")

# %% [markdown]
# Loading api data into the stocks from 'start_date = "2023-11-16"
# end_date = "2023-11-30"'

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import certifi
ca = certifi.where()

# mongodb+srv://almasfathima4:FcdtbJe82S8LL9Tu@cluster0.ibydlud.mongodb.net/
uri = "mongodb+srv://almasfathima4:FcdtbJe82S8LL9Tu@cluster0.ibydlud.mongodb.net/?retryWrites=true&w=majority"


# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'),tls=True, tlsAllowInvalidCertificates=True)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
folder_path_api = 'C:/Users/almas/Downloads/archive17/Data/API Extracted Data'
folder_path = 'C:/Users/almas/Downloads/archive17/Data/Stocks'
collection_api = db['StockMarketAPICollection']

# %%
for filename in os.listdir(folder_path_api):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path_api, filename)

        try:
            # Read CSV file into pandas DataFrame
            df = pd.read_csv(file_path)

            # Extract the ticker symbol from the filename
            ticker_symbol = filename.split('.')[0]

            # Add the 'Ticker' column to the DataFrame
            df['Ticker'] = ticker_symbol

            # Convert pandas DataFrame to list of dictionaries
            data = df.to_dict('records')

            # Insert data into MongoDB collection
            collection_api.insert_many(data)
            print(f"Inserted data from {filename} to MongoDB")
        except pd.errors.EmptyDataError:
            print(f"Empty file: {filename}, skipping...")
            continue
# Out:
# Inserted data from ABCB.csv to MongoDB
# Inserted data from ABCL.csv to MongoDB
# Inserted data from ABCM.csv to MongoDB
# Inserted data from ABEO.csv to MongoDB
# Inserted data from ABEV.csv to MongoDB
# Inserted data from ABG.csv to MongoDB
# Inserted data from ABIO.csv to MongoDB
# Inserted data from ABL.csv to MongoDB
# Inserted data from ABLLW.csv to MongoDB
# Inserted data from ABLV.csv to MongoDB
# Inserted data from ABM.csv to MongoDB
# Inserted data from ABNB.csv to MongoDB
# Inserted data from ABOS.csv to MongoDB
# Inserted data from ABR.csv to MongoDB
# Inserted data from ABSI.csv to MongoDB
# Inserted data from ABT.csv to MongoDB
# Inserted data from ABUS.csv to MongoDB
# Inserted data from ABVC.csv to MongoDB
# Inserted data from ABVX.csv to MongoDB
# Inserted data from AC.csv to MongoDB
# Inserted data from ACA.csv to MongoDB
# Inserted data from ACAB.csv to MongoDB
# Inserted data from ACABU.csv to MongoDB
# Inserted data from ACABW.csv to MongoDB
# ...

# %% [markdown]
# #Merging Data from both CSV files and data extracted from API
# [
#   {
#     $merge: {
#       into: "StockMarketAPICollection",
#       whenMatched: "merge",
#       whenNotMatched: "insert"
#     }
#   }
# ] merged two collections using MongoDb
